# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import fnmatch
from pathlib import Path

# %%
def read_csv_matrix(csv_file):
    return np.loadtxt(csv_file, delimiter=';')

# %% [markdown]
# ## Task 1

# %%
data = Path('data')
files = os.listdir('data')
task1_data = sorted(fnmatch.filter(files,'task1*'))
# group for participants
participants = []
for name in task1_data:
    p = '_'.join(name.split('_')[1:3])
    if p not in participants:
        participants.append(p)

# %%
fig, axs = plt.subplots(len(participants), 4, figsize=(12,3*len(participants)))
for i,p in enumerate(participants):
    j = 0
    for f in (500,1000):
        for reim in ('real','imag'):
            h = read_csv_matrix(data / f'task1_{p}_CSM_{reim}_f_{f}.csv')
            im = axs[i,j].imshow(h)
            fig.colorbar(im, ax=axs[i,j],fraction=0.046, pad=0.04)
            axs[i,j].set_title( f'CSM {reim} {f} Hz\n{p}')
            j += 1            
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 2

# %%
fig, axs = plt.subplots(len(participants), 4, figsize=(12,3*len(participants)))
for i,p in enumerate(participants):
    j = 0
    for f in (500,1000,2000,4000):
            h = 10*np.log10(read_csv_matrix(data / f'task2_{p}_PSF_f_{f}.csv'))
            im = axs[i,j].imshow(h.T, vmin=-30, extent=(-1,1,-1,1))
            fig.colorbar(im, ax=axs[i,j],fraction=0.046, pad=0.04)
            axs[i,j].set_title( f'PSF {f} Hz\n{p}')
            j += 1            
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 3

# %%
fig, axs = plt.subplots(len(participants), 4, figsize=(12,3*len(participants)))
for i,p in enumerate(participants):
    j = 0
    for f in (500,1000,2000,4000):
            h = read_csv_matrix(data / f'task3_{p}_CBF_f_{f}.csv')
            hmax = np.nanmax(h)
            im = axs[i,j].imshow(h.T, extent=(-2,2,-1,1), vmin=hmax-30) 
            fig.colorbar(im, ax=axs[i,j], orientation='horizontal')
            axs[i,j].set_title( f'CBF {f} Hz\n{p}')
            j += 1            
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 4

# %%
fig, axs = plt.subplots(len(participants), 4, figsize=(12,3*len(participants)))
for i,p in enumerate(participants):
    j = 0
    for f in (500,1000,2000,4000):
            h = read_csv_matrix(data / f'task4_{p}_CleanSC_f_{f}.csv')
            hmax = np.nanmax(h)
            im = axs[i,j].imshow(h.T, extent=(-2,2,-1,1), vmin=hmax-20) 
            fig.colorbar(im, ax=axs[i,j], orientation='horizontal')
            axs[i,j].set_title( f'CleanSC {f} Hz\n{p}')
            j += 1            
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 5

# %%
fig, axs = plt.subplots(len(participants), 4, figsize=(12,3*len(participants)))
for i,p in enumerate(participants):
    j = 0
    for f in (500,1000,2000,4000):
            h = read_csv_matrix(data / f'task5_{p}_CBF_f_{f}.csv')
            hmax = np.nanmax(h)
            im = axs[i,j].imshow(h.T, extent=(-2,2,-1,1), vmin=hmax-30) 
            fig.colorbar(im, ax=axs[i,j], orientation='horizontal')
            axs[i,j].set_title( f'CBF {f} Hz\n{p}')
            j += 1            
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 6

# %%
fig, ax = plt.subplots(1)
for p in participants:
    h = read_csv_matrix(data / f'task6_{p}_CBF_srcint.csv')
    ax.semilogx(h[:,0],h[:,1])
plt.legend(participants)
plt.xlabel('frequency / Hz')
plt.ylabel('Level / dB')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 7

# %%
fig, axs = plt.subplots(len(participants), 4, figsize=(12,3*len(participants)))
for i,p in enumerate(participants):
    j = 0
    for f in (500,1000,2000,4000):
            h = read_csv_matrix(data / f'task7_{p}_CleanSC_f_{f}.csv')
            hmax = np.nanmax(h)
            im = axs[i,j].imshow(h.T, extent=(-2,2,-1,1), vmin=hmax-20) 
            fig.colorbar(im, ax=axs[i,j], orientation='horizontal')
            axs[i,j].set_title( f'CleanSC {f} Hz\n{p}')
            j += 1            
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 8

# %%
fig, ax = plt.subplots(1)
for p in participants:
    h = read_csv_matrix(data / f'task8_{p}_CleanSC_srcint.csv')
    ax.semilogx(h[:,0],h[:,1])
plt.legend(participants)
plt.xlabel('frequency / Hz')
plt.ylabel('Level / dB')
plt.tight_layout()
plt.show()
